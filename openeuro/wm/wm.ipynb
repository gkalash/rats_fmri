# %%
import nibabel as nib
import glob
import os
import pandas as pd
import numpy as np

# %%
bids_root = '/neurospin/micromri/Georges/rats_white_matter/data/bids'
dataset = sorted(glob.glob(f"{bids_root}/*/*/func/**_bold.nii.gz", recursive=True))
print(f"Found {len(dataset)} BOLD fMRI files in the dataset.")
# Out:
# Found 19 BOLD fMRI files in the dataset.

# %%
brain_mask = "/neurospin/micromri/Georges/rats_white_matter/data/masks/SIGMA_Wistar_Rat_Brain_TemplatesAndAtlases_Version1.2.1/SIGMA_Rat_Anatomical_Imaging/SIGMA_Rat_Anatomical_InVivo_Template/SIGMA_InVivo_Brain_Mask.nii"
wm_mask = "/neurospin/micromri/Georges/rats_white_matter/data/masks/SIGMA_Wistar_Rat_Brain_TemplatesAndAtlases_Version1.2.1/SIGMA_Rat_Anatomical_Imaging/SIGMA_Rat_Anatomical_InVivo_Template/SIGMA_InVivo_GM_mask.nii"
